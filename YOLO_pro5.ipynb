# %% [markdown]
# https://docs.ultralytics.com/yolov5/tutorials/train_custom_data/

# %%
# %git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17485, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 17485 (delta 79), reused 30 (delta 30), pack-reused 17378 (from 3)
# Receiving objects: 100% (17485/17485), 16.35 MiB | 17.26 MiB/s, done.
# Resolving deltas: 100% (11990/11990), done.

# %%
# %pip install -r yolov5/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 65.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 70.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# %ls -l yolov5
# Out:
# total 432
# -rw-r--r-- 1 root root 14147 May 14 06:41 benchmarks.py
# -rw-r--r-- 1 root root   393 May 14 06:41 CITATION.cff
# drwxr-xr-x 2 root root  4096 May 14 06:41 classify
# -rw-r--r-- 1 root root  5419 May 14 06:41 CONTRIBUTING.md
# drwxr-xr-x 5 root root  4096 May 14 06:41 data
# -rw-r--r-- 1 root root 23762 May 14 06:41 detect.py
# -rw-r--r-- 1 root root 68578 May 14 06:41 export.py
# -rw-r--r-- 1 root root 23998 May 14 06:41 hubconf.py
# -rw-r--r-- 1 root root 34523 May 14 06:41 LICENSE
# drwxr-xr-x 4 root root  4096 May 14 06:41 models
# -rw-r--r-- 1 root root  5341 May 14 06:41 pyproject.toml
# -rw-r--r-- 1 root root 49999 May 14 06:41 README.md
# -rw-r--r-- 1 root root 48968 May 14 06:41 README.zh-CN.md
# -rw-r--r-- 1 root root  1598 May 14 06:41 requirements.txt
# drwxr-xr-x 2 root root  4096 May 14 06:41 segment
# -rw-r--r-- 1 root root 47158 May 14 06:41 train.py
# -rw-r--r-- 1 root root 40830 May 14 06:41 tutorial.ipynb
# ...

# %%
#Model przetrenowany
# !python yolov5/train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights yolov5s.pt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-14 06:43:26.566882: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747205006.848965    1183 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !ls -l yolov5
# Out:
# total 440
# -rw-r--r-- 1 root root 14147 May 14 06:41 benchmarks.py
# -rw-r--r-- 1 root root   393 May 14 06:41 CITATION.cff
# drwxr-xr-x 2 root root  4096 May 14 06:41 classify
# -rw-r--r-- 1 root root  5419 May 14 06:41 CONTRIBUTING.md
# drwxr-xr-x 5 root root  4096 May 14 06:41 data
# -rw-r--r-- 1 root root 23762 May 14 06:41 detect.py
# -rw-r--r-- 1 root root 68578 May 14 06:41 export.py
# -rw-r--r-- 1 root root 23998 May 14 06:41 hubconf.py
# -rw-r--r-- 1 root root 34523 May 14 06:41 LICENSE
# drwxr-xr-x 5 root root  4096 May 14 06:43 models
# drwxr-xr-x 2 root root  4096 May 14 06:43 __pycache__
# -rw-r--r-- 1 root root  5341 May 14 06:41 pyproject.toml
# -rw-r--r-- 1 root root 49999 May 14 06:41 README.md
# -rw-r--r-- 1 root root 48968 May 14 06:41 README.zh-CN.md
# -rw-r--r-- 1 root root  1598 May 14 06:41 requirements.txt
# drwxr-xr-x 3 root root  4096 May 14 06:44 runs
# drwxr-xr-x 2 root root  4096 May 14 06:41 segment
# -rw-r--r-- 1 root root 47158 May 14 06:41 train.py
# ...

# %%
# !python yolov5/detect.py --source drive/MyDrive/VID_20250514_074517.mp4
# Out:
# detect: weights=yolov5/yolov5s.pt, source=drive/MyDrive/VID_20250514_074517.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-418-ga493afe1 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# video 1/1 (1/791) /content/drive/MyDrive/VID_20250514_074517.mp4: 384x640 (no detections), 55.8ms
# video 1/1 (2/791) /content/drive/MyDrive/VID_20250514_074517.mp4: 384x640 (no detections), 53.2ms
# ...

# %%
# !cp /content/yolov5/runs/detect/exp/VID_20250514_074517.mp4 /content/drive/MyDrive/VID_20240529_100602_result5.mp4

# %%
#model bazowy
# !python yolov5/train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights '' --cfg yolov5s.yaml
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-14 07:01:34.755520: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747206094.791785    6206 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747206094.802248    6206 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 3
# ...

# %%
# !python yolov5/detect.py --source drive/MyDrive/VID_20250514_074517.mp4
# Out:
# detect: weights=yolov5/yolov5s.pt, source=drive/MyDrive/VID_20250514_074517.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-418-ga493afe1 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# video 1/1 (1/791) /content/drive/MyDrive/VID_20250514_074517.mp4: 384x640 (no detections), 54.7ms
# video 1/1 (2/791) /content/drive/MyDrive/VID_20250514_074517.mp4: 384x640 (no detections), 19.6ms
# ...

# %%
# !cp /content/yolov5/runs/detect/exp2/VID_20250514_074517.mp4 /content/drive/MyDrive/VID_20240529_100602_resultrandom.mp4

# %% [markdown]
# # zad 1
# Przygotuj zbiór własnoręcznie zebranych danych, z minimum 4 kategoriami. Z każdej kategorii ma być minimum 20 przykładów na minimum 40 zdjęciach. Z zaznaczeniem że jeśli zdjęcia są z jednego filmu lub jednej sytuacji, czyli mają podobne oświetlenie i ułożenie, to przykłądów powinno być minimum 2 razy więcej. Do przygotowania zbioru danych można skorzystać z narzędzi pokroju makesense.ai lub roboflow.com.

# %% [markdown]
# # zad 2
# Wybierz 3 rodzaje modelu yolov5 i wytrenuj na losowych wagach oraz na juz przetrenowanych.

# %% [markdown]
# # zad 3
# Wykonaj detekcję obydwu modeli na przykładowym filmie i przygotuj raport porównujący ze sobą modele oraz sposób trenowania.
